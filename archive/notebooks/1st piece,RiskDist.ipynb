# %% [markdown]
# # 1st piece,RiskDist

# %%
# !pip install matplotlib

import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import numpy as np

def display_railroad_network_figure(image_path):
    image = imread(image_path)

    plt.imshow(image)
    plt.axis('off')  # Turn off axis labels and ticks for cleaner display
    plt.show()

    gray_image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2GRAY)

    edges = cv2.Canny(gray_image, threshold1=30, threshold2=100)

    plt.imshow(edges, cmap='gray')
    plt.axis('off')
    plt.savefig('BK.png')
    plt.show()

if __name__ == "__main__":
    image_path = 'Network.jpg'
    display_railroad_network_figure(image_path)

# %%
image_path = 'Network.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()
import matplotlib.pyplot as plt

detroit_x, detroit_y = 200, 200
cleveland_x, cleveland_y = 300, 400

plt.imshow(image_rgb)

plt.plot([detroit_x, cleveland_x], [detroit_y, cleveland_y], color='red', linewidth=2)

plt.axis('off')
plt.show()

# %%
import pandas as pd

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)

matrix = load_forward_df.values.tolist()
matrix_load = [row[:] for row in matrix]
matrix_load_max = [row[:] for row in matrix]

for i in range(25):
    for j in range(25):
        if i != j:

            matrix_load_max[i][j] = max(matrix[i][j],matrix[j][i])

# %%
print(matrix_load[20][22])

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

ddf = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
arc_loads = ddf.values.tolist()
matrix_load_max = [row[:] for row in arc_loads]

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_backward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_forward = load_forward_df.values.tolist()
load_backward = load_backward_df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            matrix_load_max[i][j] = max(load_forward[i][j], load_forward[j][i])
            total_load = matrix_load_max[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,11.7),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

edge_labels = {(u, v): f"{data['load']:.2f}" for u, v, data in G.edges(data=True)}  # Create a dictionary of edge labels
nx.draw_networkx_edge_labels(G, node_positions, edge_labels=edge_labels, font_size=8, font_color='black')

plt.title('$0 Budget - Risk Distribution')
plt.savefig('0Risk.png')

plt.show()

# %%
print(matrix_load_max[11][10])
print(matrix_load_max[9][8])
print(matrix_load_max[9][13])

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

ddf = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
arc_loads = ddf.values.tolist()
matrix_load_max = [row[:] for row in arc_loads]

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_backward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_forward = load_forward_df.values.tolist()
load_backward = load_backward_df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            total_load = matrix_load_max[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,11.7),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

edge_loads = [data['load'] for _, _, data in G.edges(data=True)]
max_edge_load = max(edge_loads)
edge_loads_normalized = [load / max_edge_load * 10 for load in edge_loads]  # Adjust multiplier to control thickness

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

plt.title('$0 Budget - Network Risk')

highlighted_path1 = [12, 25, 24, 23, 21, 22, 7, 17, 16, 18]
highlighted_path2 = [15, 13, 11, 25, 23, 24, 8, 9, 7, 20, 18, 19]

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

for i in range(len(highlighted_path1) - 1):
    u, v = highlighted_path1[i], highlighted_path1[i+1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=3.0, edge_color='red', arrows=True, arrowstyle='->')

for i in range(len(highlighted_path2) - 1):
    u, v = highlighted_path2[i], highlighted_path2[i+1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=2.0, edge_color='blue', arrows=True, arrowstyle='->')

plt.title('$0 Budget - Changed Paths')
plt.savefig('$0 Highlighted Paths.png')

plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

ddf = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
arc_loads = ddf.values.tolist()
matrix_load_max = [row[:] for row in arc_loads]

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_backward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_forward = load_forward_df.values.tolist()
load_backward = load_backward_df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            total_load = matrix_load_max[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,11.7),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

edge_loads = [data['load'] for _, _, data in G.edges(data=True)]
max_edge_load = max(edge_loads)
edge_loads_normalized = [load / max_edge_load * 10 for load in edge_loads]  # Adjust multiplier to control thickness

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

plt.title('$0 Budget - Risk Distributiuon')

highlighted_path1 = [12, 15, 11, 10, 9, 25, 24, 23, 21, 22, 7, 20, 18]
highlighted_path2 = [15, 13,11,9,7,22,23,20,18]

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

for i in range(len(highlighted_path1) - 1):
    u, v = highlighted_path1[i], highlighted_path1[i+1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=3.0, edge_color='red', arrows=True, arrowstyle='->')

for i in range(len(highlighted_path2) - 1):
    u, v = highlighted_path2[i], highlighted_path2[i+1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=2.0, edge_color='blue', arrows=True, arrowstyle='->')

plt.title('$60k Budget - Changed Paths')
plt.savefig('$60k Highlighted Paths.png')

plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

ddf = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
arc_loads = ddf.values.tolist()
matrix_load_max = [row[:] for row in arc_loads]

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_backward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_forward = load_forward_df.values.tolist()
load_backward = load_backward_df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            total_load = matrix_load_max[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,12.5),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

highlighted_path1 = [12, 25, 24, 23, 21, 22, 7, 17, 16, 18]
highlighted_path2 = [15, 13, 11, 25, 23, 24, 8, 9, 7, 20, 18, 19]
plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

for i in range(len(highlighted_path1) - 1):
    u, v = highlighted_path1[i], highlighted_path1[i + 1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=3.0, edge_color='red', arrows=True, arrowstyle='->')

plt.title('Selecte path for commodity #14 under $0k budget scenario')
plt.savefig('$0k Highlighted Paths Red.png')

plt.show()

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

for i in range(len(highlighted_path2) - 1):
    u, v = highlighted_path2[i], highlighted_path2[i + 1]
    nx.draw_networkx_edges(G, node_positions, edgelist=[(u, v)], width=2.0, edge_color='blue', arrows=True, arrowstyle='->')

plt.title('Selecte path for commodity #21 under $0k budget scenario')
plt.savefig('$0k Highlighted Paths Blue.png')

plt.show()

# %%
import pandas as pd

load = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=1, nrows=25)

matrix2 = load.values.tolist()
matrix_load_max60k = [row[:] for row in matrix2]
for i in range(25):
    for j in range(25):
        if i != j:

            matrix_load_max60k[i][j] = max(matrix2[i][j],matrix2[j][i])

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            total_load = matrix_load_max60k[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,11.7),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

edge_loads = [data['load'] for _, _, data in G.edges(data=True)]
max_edge_load = max(edge_loads)
edge_loads_normalized = [load / max_edge_load * 10 for load in edge_loads]  # Adjust multiplier to control thickness

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

plt.title('$60k Budget - Risk Distributiuon')

plt.savefig('60KRisk.png')

plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=58, nrows=25)
adj_matrix = df.values.tolist()

ddf = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
arc_loads = ddf.values.tolist()
matrix_load_max = [row[:] for row in arc_loads]

load_forward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_backward_df = pd.read_excel('Analysis_RiskOnLinkFile.xlsx', sheet_name='Sheet1', header=None, usecols='B:Z', skiprows=30, nrows=25)
load_forward = load_forward_df.values.tolist()
load_backward = load_backward_df.values.tolist()

G = nx.Graph()

G.add_nodes_from(range(1, len(adj_matrix) + 1))  # Nodes labeled from 1 to n

for i in range(len(adj_matrix)):
    for j in range(i + 1, len(adj_matrix[i])):
        if adj_matrix[i][j] == 1:
            total_load = matrix_load_max[i][j]
            G.add_edge(i + 1, j + 1, load=total_load)  # Add 1 to node indices for labeling from 1

node_positions = {
    1: (2.5, 10.8),
    2: (2.8, 10.1),
    3: (1, 7.8),
    4: (2.9, 6.6),
    5: (0, 4),
    6: (5, 10.9),
    7: (5.5, 8.7),
    8: (3.7, 7.1),
    9: (4.2, 6),
    10: (2.9, 2.7),
    11: (4.8, 3),
    12: (6, 2.8),
    13: (3,1.5),
    14: (1.6,1),
    15: (7,0),
    16: (5.2,13.5),
    17: (5,12),
    18: (6.15,11.7),
    19: (7.9,11.2),
    20: (6.3,11),
    21: (9.5,9.8),
    22: (6.6,8.1),
    23: (8,6.5),
    24: (6.5,6),
    25: (6,5),
}

plt.figure(figsize=(8, 6))

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='chartreuse', label=True)

node_labels = {node: node for node in G.nodes()}  # Create a mapping to label nodes from 1
nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10)

edge_loads = [data['load'] for _, _, data in G.edges(data=True)]
max_edge_load = max(edge_loads)
edge_loads_normalized = [load / max_edge_load * 10 for load in edge_loads]  # Adjust multiplier to control thickness

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='gray', alpha=0.7)

plt.title('$0 Budget - Risk Distributiuon')
plt.savefig('0Risk.png')

plt.figure()

plt.show()

plt.figure(figsize=(10, 8))

background_rect = Rectangle((-1, -1), 12, 10, color='darkblue', zorder=-1)
plt.gca().add_patch(background_rect)

nx.draw_networkx_nodes(G, node_positions, node_size=400, node_color='silver', label=True)

nx.draw_networkx_labels(G, node_positions, labels=node_labels, font_size=10, font_color='black')

max_edge_load = max(edge_loads)
edge_loads_normalized = [load / max_edge_load * 10 for load in edge_loads]

nx.draw_networkx_edges(G, node_positions, width=edge_loads_normalized, edge_color='silver', alpha=0.7)

plt.title('$0 Budget - Risk Distribution', color='white', fontsize=14)

plt.axis('off')

plt.savefig('0Risk.png', facecolor='none', bbox_inches='tight', pad_inches=0.1, transparent=True)

plt.show()
