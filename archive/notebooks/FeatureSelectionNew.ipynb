# %% [markdown]
# # FeatureSelectionNew

# %%
pip install dython

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression  # You can choose an appropriate model

data = pd.read_csv('datawithTime.csv')

Continuous_features_cols = ['CARS', 'TEMP', 'TRNSPD', 'TONS', 'POSITON1', 'HEADEND1', 'LOADF1', 'EMPTYF1', 'HIGHSPD', 'hour', 'minute']
categorical_features_cols = ['RAILROAD', 'YEAR', 'MONTH', 'DAY', 'STATE ', 'VISIBLTY', 'WEATHER',
                             'TYPEQ', 'TRKCLAS', 'TYPTRK', 'CAUSE', 'ACCTRK']

X = data[Continuous_features_cols + categorical_features_cols]
y = data['CASINJ']

model = LinearRegression()  # You can replace this with a different model

num_features_to_select = None  # Set the number of features you want to select
rfe = RFE(model, n_features_to_select=num_features_to_select)

rfe.fit(X, y)

feature_ranking = rfe.ranking_

selected_feature_names = [feature for feature, ranking in zip(X.columns, feature_ranking) if ranking == 1]

optimal_num_features = rfe.n_features_

final_model = LinearRegression()  # Replace with your model of choice
final_model.fit(X[selected_feature_names], y)

feature_significance = final_model.coef_

print("Selected Features:", selected_feature_names)
print("Optimal Number of Selected Features:", optimal_num_features)
print("Significance of Selected Features:", feature_significance)

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

data = pd.read_csv('datawithTime.csv')

Continuous_features_cols = ['CARS', 'TEMP', 'TRNSPD', 'TONS', 'POSITON1', 'HEADEND1', 'LOADF1', 'EMPTYF1', 'HIGHSPD', 'hour', 'minute']
categorical_features_cols = ['RAILROAD', 'YEAR', 'MONTH', 'DAY', 'STATE ', 'VISIBLTY', 'WEATHER',
                             'TYPEQ', 'TRKCLAS', 'TYPTRK', 'CAUSE', 'ACCTRK']

X = data[Continuous_features_cols + categorical_features_cols]
y = data['CASINJ']

model = RandomForestRegressor(n_estimators=100)  # You can adjust hyperparameters as needed

num_features_to_select = None  # Set the number of features you want to select
rfe = RFE(model, n_features_to_select=num_features_to_select)

rfe.fit(X, y)

model.fit(X, y)

feature_ranking = rfe.ranking_

selected_feature_names = [feature for feature, ranking in zip(X.columns, feature_ranking) if ranking == 1]

optimal_num_features = rfe.n_features_

selected_feature_importances = model.feature_importances_

print("Selected Features:", selected_feature_names)
print("Optimal Number of Selected Features:", optimal_num_features)
print("Feature Importances for Selected Features:", selected_feature_importances)
